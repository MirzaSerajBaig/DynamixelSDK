# %% [markdown]
# <a href="https://colab.research.google.com/github/MirzaSerajBaig/DynamixelSDK/blob/master/ExcelR_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd;
l=[1,2,3,4]
k=['saree','dress','rat']

n=pd.DataFrame(l)
n
mydatase={
    'cars':['BMW','Mercedes','Volvo'],
    'passings':['3','4','5']
}
myvar=pd.DataFrame(mydatase)
myvar
# Out:
#        cars passings
# 0       BMW        3
# 1  Mercedes        4
# 2     Volvo        5

# %%
import pandas as pd
a=[1,2,3,4]
n=pd.Series(a)
print(n)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
 import random
 coins=['H','T']
 toss=random.choice(coins)
 toss

 import random
 dice=[1,2,3,4,5,6]
 toss=random.choice(dice)
 toss
# Out:
# 1

# %%
import pandas
mydataset = {
  'cars': ["BMW", "Volvo", "Ford"],
  'passings': [3, 7, 2]
}
myvar = pandas.DataFrame(mydataset) ## check session16 notes
myvar
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
import pandas as pd
a = [1, 7, 2]
myvar = pd.Series(a)


print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
mydice=[3,7,7]
newdice=pd.Series(mydice,index=['x','y','z'])
newdice
# Out:
# x    3
# y    7
# z    7
# dtype: int64

# %%
calories={'day1':420,'day2':380,'day3':480}
myvari=pd.Series(calories)
myvari    ##DataFrames is more systematic as it has row & column specifically whereas series don't has
##DataFrames is for multiple column and series is for single column.
# Out:
# day1    420
# day2    380
# day3    480
# dtype: int64

# %%
import pandas as pd
war=pd.read_csv("/content/data.csv")
war
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
war.head() ## by default it will show first 5 values and if want to show
#  specific number values then we have write as war.head(10)i.e the row number
# is inside the the braces.
war.head(10)
war.tail() ## by default it will show last 5 values and if want to show
#  specific number values then we have write as war.tail(10)i.e the row number
war.tail(10)
war.info() ## it is used to give information about datatypes.
##csv is comma seperated file.
war.describe  ## it will it is used to give information about all the column
# one by one.
war.columns  ## it will show all the column
war.Pulse   ## it will show specific column.
war.shape  ## it will no of rows and column respectively
war.value_counts  ##It will show all column
war.value_counts('Pulse')  ## it will show pulse column
war.isnull().sum()   ## it will show the null value
war[['Pulse','Maxpulse']]    ## it will show two data which is pulse and Maxpulse.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  169 non-null    int64
#  1   Pulse     169 non-null    int64
#  2   Maxpulse  169 non-null    int64
#  3   Calories  164 non-null    float64
# dtypes: float64(1), int64(3)
# memory usage: 5.4 KB
#      Pulse  Maxpulse
# 0      110       130
# 1      117       145
# 2      103       135
# 3      109       175
# 4      117       148
# ..     ...       ...
# 164    105       140
# 165    110       145
# 166    115       145
# 167    120       150
# 168    125       150
#
# [169 rows x 2 columns]

# %%
### Numpy- Numerical Python. It is used for computation and it is faster
# Numpy aims to provide an array object that is upto 50x faster than traditional python list.
#Numpy is a python library and is written partially in python, but most of
# the parts that require fast computation are written in C,C++.
# we can do 1D,2D,3D

# %%
import numpy as np
arr=np.array([1]) ##0D array
arr
print(arr)

import numpy as np
arr=np.array([1,2,3,5]) ##1D array
arr
print(arr)
# Out:
# [1]
# [1 2 3 5]

# %%
import numpy as np
arr=np.array([[1,2,3,5],[3,5,6]]) #2D array
arr
print(arr)
# Out:
# [list([1, 2, 3, 5]) list([3, 5, 6])]
# <ipython-input-43-014631d46f6b>:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr=np.array([[1,2,3,5],[3,5,6]])

# %%
##### Matplotlib###
# c:\Users\Your Name>pip install matplotlib   ## command for installing matplotllib
# Matplotlib is a low level graph plotting library in python that serves as a visualization utility.
# Matplotlib was created by John D. Hunter.
# Matplotlib is open source(its free to use )and we can use it freely.

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([0,6])
ypoints=np.array([0,6])
plt.plot(xpoints,ypoints)
plt.show()

# %%
# Plotting Without Line:- Example-Draw two points in the diagram, one at position (1, 3) and one in position (8, 10):
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,8])
ypoints=np.array([3,10])
plt.plot(xpoints,ypoints,'o')  #To plot only the markers, you can use shortcut string notation parameter 'o', which means 'rings'.

# Example2-Draw a line in a diagram from position (1, 3) to (2, 8) then to (6, 1) and finally to position (8, 10):
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])
plt.plot(xpoints,ypoints)
plt.show()
## different line styles###

xpoints=np.array([0,6])
ypoints=np.array([0,6])
plt.plot(xpoints,ypoints,linestyle="dotted")
plt.show()
## plotting without x axis
import matplotlib.pyplot as plt
import numpy as np

ypoints=np.array([0,6])
plt.plot(ypoints)
plt.show()


xpoints=np.array([0,6])
ypoints=np.array([0,6])
plt.plot(xpoints,ypoints,linestyle="dashed")
plt.show()

# %%
## create labels for a plot
import matplotlib.pyplot as plt
import  numpy as np
xpoints=np.array([0,6])
ypoints=np.array([0,6])
plt.plot(xpoints,ypoints,linestyle="dotted")
plt.title('Sports watch data')
plt.xlabel('Average pulse')
plt.ylabel('calories')
plt.show()

# %%
###Set Font Properties for Title and Labels###
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([0,6])
ypoints=np.array([0,6])
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.plot(xpoints,ypoints,linestyle="dashed")
plt.title('Sports watch data',fontdict=font1)
plt.xlabel('Average pulse',fontdict=font2)
plt.ylabel('calories',fontdict=font1)
plt.show()

# %%
## Add Grid lines to a plot###
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,2,6,5,8])
ypoints=np.array([3,8,1,10])
font1={'family':'serif','color':'blue','size':'20'}
font2={'family':'serif','color':'red','size':'15'}
plt.title('sports watch data',fontdict=font1)
plt.xlabel('Average pulse',fontdict=font1)
plt.ylabel('calories',fontdict=font2)
# plt.grid('yaxis')
# plt.grid('xaxis')
# plt.grid('y')
# plt.grid('x')
plt.grid()
# plt.grid(axis= 'x')

# %%
## Scatter Plots ###
# The scatter() function plots one dot for each observation. It needs
#  two arrays of the same length,
# one for the values of the x-axis, and one for values on the y-axis:
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,2,6,5,8,9,8,7,5])
ypoints=np.array([3,8,1,10,7,6,5,8,9])
plt.scatter(xpoints,ypoints)


xpoints=np.array([1,2,0,5,8,9,8,7,5])
ypoints=np.array([3,8,1,9,7,6,5,8,9])
plt.scatter(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
x=np.random.normal(170,10,220)
y=np.random.normal(150,10,330)
xpoints=np.array([1,2,6,5,8,9,8,7,5])
ypoints=np.array([3,8,1,10,7,6,5,8,9])
plt.bar(xpoints,ypoints,width=0.01)

plt.barh(xpoints,ypoints,color='red',)  # for vertical is bar & for horizintal is barh

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-e6c1420fd2d5> in <cell line: 11>()
#       9
#      10 plt.barh(xpoints,ypoints,color='red',)  # for vertical is bar & for horizintal is barh
# ---> 11 plt.bar(x,y)
#      12 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2437         x, height, width=0.8, bottom=None, *, align='center',
#    2438         data=None, **kwargs):
# -> 2439     return gca().bar(
#    2440         x, height, width=width, bottom=bottom, align=align,
#    2441         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
x=np.random.normal(170,10,250) # 170= peak value, 10= minimum value, 250= maximum value.
# print(x)
plt.hist(x,color='red')

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
x=np.random.normal(170,10,220)
y=np.random.normal(150,10,220)
plt.bar(x,y)
plt.show()
x=pd.DataFrame(x)
x.describe()
# Out:
#                 0
# count  220.000000
# mean   170.535089
# std      9.911165
# min    149.833416
# 25%    162.443524
# 50%    170.518800
# 75%    177.444420
# max    193.965584

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
x=np.array([1,2,6,5])
mylabels=['Apples','Banana','cherry','pastries']
plt.pie(x, labels=mylabels)# labels
myexplode =[0.2,0,0,0]
# plt.pie(x, labels=mylabels, explode=myexplode)  #Maybe you want one of the wedges to stand out? The explode parameter allows you to do that.
# The explode parameter, if specified, and not None, must be an array with one value for each wedge.
# Each value represents how far from the center each wedge is displayed:

plt.legend(title='Four Fruits')  # Adding a legend with a header
# fig,ax=plt.subplots()   # fig, ax- each part of pie plot
# # ax: It is an instance of the Axes class in Matplotlib, representing a single plot within a figure. ax is usually obtained by calling plt.subplots() or plt.subplot() to create a figure and axes.
# # autopct: It is an optional parameter that controls the display format of the autopct (automatic percent) labels on the pie chart. In this case, '%1.1f%%' is used as the format string. It formats the autopct labels to display the percentage value with one digit after the decimal point followed by the '%' symbol
# plt.pie(x,labels=mylabels, autopct='%1.1f%%')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
x=np.array([1,2,6,5])
mylabels=['Apples','Banana','cherry','pastries']
# plt.pie(x, labels=mylabels)# labels
fig,ax=plt.subplots()   # fig, ax- each part of pie plot
# ax: It is an instance of the Axes class in Matplotlib, representing a single plot within a figure. ax is usually obtained by calling plt.subplots() or plt.subplot() to create a figure and axes.
# autopct: It is an optional parameter that controls the display format of the autopct (automatic percent) labels on the pie chart. In this case, '%1.1f%%' is used as the format string. It formats the autopct labels to display the percentage value with one digit after the decimal point followed by the '%' symbol
plt.pie(x,labels=mylabels, autopct='%1.2f%%')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,2,3,4,5])
y=('Apple','Banana','guava','cherry','grapes')
plt.pie(x,labels=y)
plt.show()

# %%
###### Seaborn##################
import seaborn as sns
df=sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import seaborn as sns
f=sns.load_dataset()

# %%
# categories of plt- variable is like column here.
# categorial - string will be categorical e.g male n female.
# univariate is single features  i.e one column, bivariate ia two feature i.e two column , multiple variayte is more column
#
import seaborn as sns
df=sns.load_dataset('tips')
df.head(20)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 15       21.58  3.92    Male     No  Sun  Dinner     2
# ...

# %%
sns.lineplot(x='tip',y='total_bill',data=df)   # here data is name of dataset ours is df so written df
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
df.value_counts(['sex','smoker'])
# Out:
# sex     smoker
# Male    No        97
#         Yes       60
# Female  No        54
#         Yes       33
# dtype: int64

# %%
sns.countplot(x='smoker',data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.countplot(x='smoker',data=df)
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
sns.pairplot

# %%
## Pair plot
sns.pairplot(data=df,hue='tip') # here compare withx, y axis with tips. hue is alaways for selecting color.

# %%
##scatter plot##
sns.scatterplot(x='total_bill',y='tip',data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.histplot(data=df,x="size")
# Out:
# <Axes: xlabel='size', ylabel='Count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df=sns.load_dataset('flights')
df.head(230)
sns.lineplot(x='year',y='passengers', data=df)
plt.legend(title='Flights')
plt.xlabel('Year')
plt.ylabel('flight of passengers')
plt.figure(figsize=(10,7))
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.stripplot(x='year',y='passengers', data=df)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.swarmplot(x='year',y='passengers', data=df)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
import seaborn as sns
df=sns.load_dataset('exercise')
df.head()
sns.barplot(x='id',y='diet',data= df)
# Out:
# <Axes: xlabel='id', ylabel='diet'>

# %%
sns.barplot(x='diet',y='id', data=df)
# Out:
# <Axes: xlabel='diet', ylabel='id'>

# %%
sns.countplot(x='kind', data=df)
# Out:
# <Axes: xlabel='kind', ylabel='count'>

# %%
sns.stripplot(x='id',y='pulse', data=df)
# Out:
# <Axes: xlabel='id', ylabel='pulse'>

# %%
sns.swarmplot(x='id',y='time',data=df, color='red')
# Out:
# <Axes: xlabel='id', ylabel='time'>

# %%
###After minimun and maximun point if something is there that is called outliers.
df=sns.load_dataset('iris')

df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.boxplot(x='species',y='sepal_length', data=df)
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
### Numerical Data ####
import seaborn as sns
sns.displot(x='sepal_width', data=df)

# %%
sns.histplot(x='sepal_width', data=df)
# Out:
# <Axes: xlabel='sepal_width', ylabel='Count'>

# %%
#Bivariate- two variable column.

# %%
#Heat maps. The column which are  highly correlated means they very similiar to
# each other  so we can drop one of the colunm . this process is done for cleaning the dataset
# so that size can reduce.
df=sns.load_dataset('diamonds')
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.corr()
# Out:
# <ipython-input-11-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.028224  0.181618  0.921591  0.975094  0.951722  0.953387
# depth  0.028224  1.000000 -0.295779 -0.010647 -0.025289 -0.029341  0.094924
# table  0.181618 -0.295779  1.000000  0.127134  0.195344  0.183760  0.150929
# price  0.921591 -0.010647  0.127134  1.000000  0.884435  0.865421  0.861249
# x      0.975094 -0.025289  0.195344  0.884435  1.000000  0.974701  0.970772
# y      0.951722 -0.029341  0.183760  0.865421  0.974701  1.000000  0.952006
# z      0.953387  0.094924  0.150929  0.861249  0.970772  0.952006  1.000000

# %%
sns.heatmap(data=df.corr())
# Out:
# <ipython-input-12-afb2b4e09bbc>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df.corr())
# <Axes: >

# %%
sns.heatmap(data=df.corr(),cmap='tab20')
# Out:
# <ipython-input-13-f9c4f6d77865>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df.corr(),cmap='tab20')
# <Axes: >

# %%
sns.heatmap(data=df.corr(),cmap='tab20',center=0)
# Out:
# <ipython-input-15-0b65427c50d5>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df.corr(),cmap='tab20',center=0)
# <Axes: >

# %%
sns.heatmap(data=df.corr(),annot=True)
# Out:
# <ipython-input-16-aa355c3d392f>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df.corr(),annot=True)
# <Axes: >

# %%
sns.heatmap(data=df.corr(),linewidth=2,linecolor='Red')
# Out:
# <ipython-input-19-a237e1112bbb>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df.corr(),linewidth=2,linecolor='Red')
# <Axes: >

# %%
### Joint Plot###
df=sns.load_dataset('mpg')
df.head()
sns.jointplot(data=df, x='mpg', y='acceleration',hue='model_year')

# %%
df=sns.load_dataset('penguins')
df.head()
sns.jointplot(data=df,x='bill_length_mm',y='bill_depth_mm', kind='hex')

# %%
sns.jointplot(data=df,x='bill_length_mm',y='bill_depth_mm', kind='kde')

# %%
row= int(input('Enter the number'))
for i in range(1,row+1):
  for j in range(1, i+1):
    print('*',end='')
  print()
# Out:
# Enter the number3
# *
# **
# ***
